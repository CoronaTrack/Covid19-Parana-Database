# %%
import pandas as pd
import urllib.request

# !apt install python3-tk ghostscript
# !pip install camelot-py[cv]
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ghostscript is already the newest version (9.26~dfsg+0-0ubuntu0.18.04.12).
# python3-tk is already the newest version (3.6.9-1~18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# ...

# %%
import camelot
url = 'http://www.saude.pr.gov.br/arquivos/File/CORONA_19032020.pdf'
req = urllib.request.urlretrieve(url, 'covid19_PR.pdf')
tables = camelot.read_pdf('covid19_PR.pdf')
tables.export('covid19_PR.csv', f='csv', compress=True) # json, excel, html, sqlite
df = tables[1].df
df = df.iloc[ 0:df.shape[0]-1 , 1:df.shape[1]]
df.to_csv('covid19_PR.csv', index=False, sep=';')
df
# Out:
#                            1            2            3          4      5
# 0                  MUNICÍPIO  CONFIRMADOS  DESCARTADOS  SUSPEITOS  TOTAL
# 1                  Guaratuba                                    1      1
# 2                   Matinhos                         2          1      3
# 3                  Paranaguá                         1          2      3
# 4        Almirante Tamandaré                                    1      1
# 5                  Araucária                         1                 1
# 6                Campo Largo            1            1                 2
# 7                   Curitiba           17           64         54    135
# 8       São José dos Pinhais                         2                 2
# 9                   Carambeí                                    1      1
# 10              Ponta Grossa                         8         19     27
# 11                     Irati                                    1      1
# ...
